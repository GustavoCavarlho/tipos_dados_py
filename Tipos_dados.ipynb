# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoCavarlho/tipos_dados_py/blob/main/Tipos_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tipos de dados no pyton - revisão

#int

idade = 17
print("idade")
print(idade)
print(type(idade))

#
#float (valor com casas decimais)
texto = "sim"

autura = 1.60
print("autura")
print(autura)
print(type(autura))
#str



#booleano (sim ou não)

briga = False
print("briga")
print(briga)
print(type(briga))
#lista

mercado = [1,2,3,4,]
print("mercado")
print(mercado)
print(type(mercado))
#tuplas

localizacao = (11, 930)

#set

numeros = {1,2,2,3,3,4}

print("numeros")
print(numeros)
print(type(numeros))

#dict
pessoas = {"nome": "Edvaldo", "idade":35,}
print("pessoas")
print(pessoas)
print(type(pessoas))
#None type

valor = None
print("valor")
print(valor)
print(type(valor))
# Out:
# idade
# 17
# <class 'int'>
# autura
# 1.6
# <class 'float'>
# briga
# False
# <class 'bool'>
# mercado
# [1, 2, 3, 4]
# <class 'list'>
# numeros
# {1, 2, 3, 4}
# <class 'set'>
# pessoas
# {'nome': 'Edvaldo', 'idade': 35}
# <class 'dict'>
# valor
# None
# <class 'NoneType'>
